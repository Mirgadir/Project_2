# %%
import datetime as dt
import numpy as np
import pandas as pdimport
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, MetaData, Table, Column
from flask import Flask, jsonify

# %%
# !pip install psycopg2
# db Setup
engine = create_engine("postgres://nczozxhlrcyoqp:e50ab3fc6da28bf87e8e09a08841defd50a1ed73eb74febe6fcf02a24c9688e0@ec2-50-17-178-87.compute-1.amazonaws.com:5432/daq2j0ovj687mc")
base = automap_base()
base.prepare(engine, reflect=True)
session = Session(engine)


fire_table = base.classes.fires_2013_2017
# Out:
# [('Natural /Other/ known ', 'North Dakota', 1, 1, 2013),
#  ('Natural /Other/ known ', 'North Dakota', 1, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 1, 1, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 1, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 2, 1, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Utah', 2, 1, 2013),
#  ('Human/Equipment /Power Line ', 'Oklahoma', 4, 1, 2013),
#  ('Human/Accidental/Recreation', 'California', 5, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 5, 1, 2013),
#  ('Human/Fire Use /Slash Burning ', 'South Dakota', 5, 1, 2013),
#  ('Human/Accidental/Recreation', 'California', 6, 1, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 7, 1, 2013),
#  ('Natural /Other/ known ', 'South Dakota', 8, 1, 2013),
#  ('Human/Equipment /Other/ known ', 'Montana', 8, 1, 2013),
#  ('Human/Fire Use /Land Clearing ', 'Oklahoma', 8, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Florida', 8, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 8, 1, 2013),
#  ('Human/Accidental/Recreation', 'Maryland', 8, 1, 2013),
#  ('Human', 'New Mexico', 9, 1, 2013),
#  ('Human/Equipment /Power Line ', 'South Dakota', 9, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'South Dakota', 10, 1, 2013),
#  ('Human/Fire Use /Burning Dump ', 'Arizona', 10, 1, 2013),
#  ('Undetermined', 'North Carolina', 10, 1, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 10, 1, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 11, 1, 2013),
#  ('Human/Other', 'Mississippi', 11, 1, 2013),
#  ('Human/Other', 'Mississippi', 12, 1, 2013),
#  ('Human/Accidental/Recreation', 'Florida', 12, 1, 2013),
#  ('Human/Equipment /Vehicle ', 'California', 12, 1, 2013),
#  ('Human/Equipment /Vehicle ', 'California', 13, 1, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arizona', 13, 1, 2013),
#  ('Human/Accidental/Recreation', 'Texas', 14, 1, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 14, 1, 2013),
#  ('Human', 'New York', 14, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 15, 1, 2013),
#  ('Human/Accidental/Escaped Rx', 'Georgia', 15, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Utah', 15, 1, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 16, 1, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Oklahoma', 16, 1, 2013),
#  ('Undetermined', 'Arizona', 16, 1, 2013),
#  ('Human/Incendiary /Field Burning ', 'New Mexico', 17, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oklahoma', 17, 1, 2013),
#  ('Human', 'Oregon', 17, 1, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Arizona', 17, 1, 2013),
#  ('Human/Railroads /Other/ unknown ', 'Montana', 17, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 17, 1, 2013),
#  ('Human/Incendiary /Trash Burning ', 'New Mexico', 18, 1, 2013),
#  ('Undetermined', 'Puerto Rico', 18, 1, 2013),
#  ('Human/Incendiary /Blasting ', 'California', 18, 1, 2013),
#  ('Human/Incendiary /Other/ known ', 'Arizona', 18, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 18, 1, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 19, 1, 2013),
#  ('Human/Fire Use /Resource Mgmt ', 'Oklahoma', 19, 1, 2013),
#  ('Human/Incendiary /Other/ known ', 'New York', 19, 1, 2013),
#  ('Human/Campfire /Other/ unknown ', 'California', 20, 1, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Oklahoma', 20, 1, 2013),
#  ('Human', 'Nevada', 21, 1, 2013),
#  ('Human/Equipment /Vehicle ', 'Tennessee', 21, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 21, 1, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'Indiana', 21, 1, 2013),
#  ('Human/Incendiary /Other/ known ', 'Oklahoma', 21, 1, 2013),
#  ('Human/Fire Use /Other/ known ', 'Arizona', 21, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 22, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 22, 1, 2013),
#  ('Human/Equipment /Vehicle ', 'Utah', 22, 1, 2013),
#  ('Human/Juveniles /Other/ known ', 'Arizona', 23, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 23, 1, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 23, 1, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 24, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Utah', 24, 1, 2013),
#  ('Human/Other', 'New Mexico', 24, 1, 2013),
#  ('Human/Accidental/Recreation', 'South Carolina', 24, 1, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'South Dakota', 24, 1, 2013),
#  ('Human/Equipment /Vehicle ', 'Colorado', 25, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 25, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'South Dakota', 26, 1, 2013),
#  ('Human/Arson/Adult', 'California', 26, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 26, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 26, 1, 2013),
#  ('Human/Equipment /Vehicle ', 'Oklahoma', 26, 1, 2013),
#  ('Human/Incendiary /Other/ known ', 'Montana', 26, 1, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'South Dakota', 27, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Florida', 27, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Florida', 27, 1, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'Mississippi', 27, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'South Dakota', 27, 1, 2013),
#  ('Human/Fire Use /Slash Burning ', 'Mississippi', 28, 1, 2013),
#  ('Undetermined', 'Mississippi', 28, 1, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 28, 1, 2013),
#  ('Human/Arson/Adult', 'Louisiana', 28, 1, 2013),
#  ('Human/Arson/Adult', 'Louisiana', 28, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Texas', 28, 1, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'South Dakota', 28, 1, 2013),
#  ('Human/Other', 'Georgia', 29, 1, 2013),
#  ('Human/Equipment /Vehicle ', 'Mississippi', 29, 1, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 30, 1, 2013),
#  ('Undetermined', 'South Carolina', 30, 1, 2013),
#  ('Natural /Lightning ', 'Arizona', 31, 1, 2013),
#  ('Human/Equipment /Other/ known ', 'South Dakota', 31, 1, 2013),
#  ('Human/Accidental/Industrial', 'Texas', 31, 1, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 31, 1, 2013),
#  ('Undetermined', 'Mississippi', 1, 2, 2013),
#  ('Undetermined', 'Mississippi', 1, 2, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Mississippi', 1, 2, 2013),
#  ('Human/Equipment /Other/ unknown ', 'Oklahoma', 1, 2, 2013),
#  ('Human/Equipment /Vehicle ', 'South Dakota', 2, 2, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Oklahoma', 2, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 2, 2, 2013),
#  ('Undetermined', 'Puerto Rico', 2, 2, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Oregon', 2, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 2, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'New York', 2, 2, 2013),
#  ('Human/Accidental/Recreation', 'California', 3, 2, 2013),
#  ('Human/Equipment /Other/ known ', 'Florida', 3, 2, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Montana', 3, 2, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Montana', 3, 2, 2013),
#  ('Undetermined', 'Puerto Rico', 3, 2, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 3, 2, 2013),
#  ('Human', 'South Dakota', 4, 2, 2013),
#  ('Human/Incendiary /Field Burning ', 'Arizona', 4, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 4, 2, 2013),
#  ('Human/Equipment /Other/ unknown ', 'Oklahoma', 4, 2, 2013),
#  ('Human/Accidental/Industrial', 'Florida', 4, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oklahoma', 4, 2, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Alabama', 4, 2, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Alabama', 4, 2, 2013),
#  ('Human/Fire Use /Trash Burning ', 'South Dakota', 5, 2, 2013),
#  ('Undetermined', 'Puerto Rico', 5, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 5, 2, 2013),
#  ('Human/Smoking /Smoking ', 'Arizona', 6, 2, 2013),
#  ('Human/Accidental/Recreation', 'California', 6, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Montana', 6, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 7, 2, 2013),
#  ('Undetermined', 'North Carolina', 7, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 8, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Montana', 9, 2, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'New Mexico', 9, 2, 2013),
#  ('Undetermined', 'Puerto Rico', 9, 2, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 9, 2, 2013),
#  ('Human/Accidental/Agricultural', 'Colorado', 9, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 9, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oklahoma', 10, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 10, 2, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 11, 2, 2013),
#  ('Human/Accidental/Escaped Rx', 'Florida', 11, 2, 2013),
#  ('Natural /Other/ unknown ', 'California', 11, 2, 2013),
#  ('Human/Incendiary /Other/ known ', 'South Dakota', 11, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 12, 2, 2013),
#  ('Human/Other', 'Maryland', 12, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 12, 2, 2013),
#  ('Human/Other', 'Maryland', 12, 2, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arizona', 12, 2, 2013),
#  ('Human/Equipment /Vehicle ', 'California', 13, 2, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'South Dakota', 13, 2, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 13, 2, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Montana', 13, 2, 2013),
#  ('Human/Fire Use /Trash Burning ', 'South Dakota', 13, 2, 2013),
#  ('Human/Accidental/Recreation', 'California', 14, 2, 2013),
#  ('Human/Accidental/Industrial', 'North Carolina', 14, 2, 2013),
#  ('Human/Incendiary /Trash Burning ', 'California', 14, 2, 2013),
#  ('Human/Incendiary /Trash Burning ', 'North Dakota', 14, 2, 2013),
#  (None, 'Oregon', 6, 5, 2013),
#  ('Human/Accidental/Recreation', 'California', 15, 2, 2013),
#  ('Human/Equipment /Exhaust ', 'Oklahoma', 15, 2, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Arizona', 15, 2, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 15, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Montana', 15, 2, 2013),
#  ('Human/Accidental/Agricultural', 'Texas', 15, 2, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 16, 2, 2013),
#  ('Human/Other', 'Puerto Rico', 16, 2, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Montana', 16, 2, 2013),
#  ('Human/Equipment /Vehicle ', 'California', 16, 2, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Oklahoma', 16, 2, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Montana', 16, 2, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Mississippi', 16, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 17, 2, 2013),
#  ('Human/Fire Use /Other/ known ', 'New York', 17, 2, 2013),
#  ('Human/Incendiary /Slash Burning ', 'New Mexico', 17, 2, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 17, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 17, 2, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'New Mexico', 17, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 17, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 17, 2, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'South Dakota', 17, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 17, 2, 2013),
#  ('Human/Incendiary /Slash Burning ', 'California', 17, 2, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 17, 2, 2013),
#  ('Human/Campfire /Other/ unknown ', 'Nevada', 17, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 18, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 18, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 18, 2, 2013),
#  ('Undetermined', 'Kansas', 18, 2, 2013),
#  ('Human/Fire Use /Trash Burning ', 'California', 18, 2, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 18, 2, 2013),
#  ('Human/Fire Use /Land Clearing ', 'Oklahoma', 18, 2, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 18, 2, 2013),
#  ('Human/Equipment /Power Line ', 'Mississippi', 18, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Maryland', 18, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Idaho', 18, 2, 2013),
#  ('Human/Fire Use /Slash Burning ', 'Oklahoma', 18, 2, 2013),
#  ('Undetermined', 'Alabama', 19, 2, 2013),
#  ('Human/Equipment /Power Line ', 'South Dakota', 19, 2, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Utah', 19, 2, 2013),
#  ('Human/Equipment /Power Line ', 'South Dakota', 19, 2, 2013),
#  ('Human/Accidental/Agricultural', 'Oklahoma', 19, 2, 2013),
#  ('Human/Incendiary /Other/ known ', 'Arizona', 19, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oregon', 19, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 20, 2, 2013),
#  ('Undetermined', 'Texas', 21, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 21, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 21, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Idaho', 22, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 22, 2, 2013),
#  ('Human/Incendiary /Other/ known ', 'Arizona', 23, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 23, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'South Dakota', 24, 2, 2013),
#  ('Natural /Lightning ', 'Georgia', 24, 2, 2013),
#  ('Human/Accidental/Agricultural', 'Nevada', 24, 2, 2013),
#  ('Natural /Lightning ', 'Georgia', 24, 2, 2013),
#  ('Human/Equipment /Vehicle ', 'New Mexico', 24, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 24, 2, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 24, 2, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arizona', 25, 2, 2013),
#  ('Human/Incendiary /Field Burning ', 'Arizona', 25, 2, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 25, 2, 2013),
#  ('Human/Accidental/Industrial', 'Texas', 25, 2, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 26, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 26, 2, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arizona', 26, 2, 2013),
#  ('Human/Other', 'Texas', 26, 2, 2013),
#  ('Human/Arson/Adult', 'Oklahoma', 26, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 26, 2, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'New Mexico', 26, 2, 2013),
#  ('Human/Incendiary /Recurrent ', 'Oregon', 27, 2, 2013),
#  ('Human/Equipment /Vehicle ', 'New Mexico', 27, 2, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 27, 2, 2013),
#  ('Human', 'Georgia', 28, 2, 2013),
#  ('Human/Accidental/Agricultural', 'Texas', 28, 2, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 28, 2, 2013),
#  ('Human/Fire Use /Land Clearing ', 'New Mexico', 28, 2, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 28, 2, 2013),
#  ('Human/Incendiary /Other/ known ', 'Nevada', 1, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 1, 3, 2013),
#  ('Undetermined', 'Texas', 1, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 2, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Montana', 2, 3, 2013),
#  ('Human/Accidental/Agricultural', 'Montana', 2, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 2, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'New Mexico', 2, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 2, 3, 2013),
#  ('Natural /Other/ known ', 'South Dakota', 2, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'California', 2, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'Mississippi', 3, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'Oregon', 3, 3, 2013),
#  ('Human/Accidental/Agricultural', 'Texas', 3, 3, 2013),
#  ('Undetermined', 'North Carolina', 3, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 3, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 3, 3, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 3, 3, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 3, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'South Dakota', 3, 3, 2013),
#  ('Natural /Other/ unknown ', 'Florida', 4, 3, 2013),
#  ('Human/Accidental/Recreation', 'Florida', 4, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arkansas', 4, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'New Mexico', 4, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'New Mexico', 4, 3, 2013),
#  ('Human/Equipment /Exhaust ', 'Arizona', 4, 3, 2013),
#  (None, 'Oregon', 6, 5, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 4, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'Oklahoma', 4, 3, 2013),
#  ('Human/Campfire /Other/ unknown ', 'Nevada', 5, 3, 2013),
#  ('Human/Campfire /Other/ unknown ', 'Nevada', 5, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 5, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'Nevada', 5, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arkansas', 5, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Virginia', 5, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 5, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 5, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 5, 3, 2013),
#  (None, 'Colorado', 5, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 5, 3, 2013),
#  ('Undetermined', 'Texas', 5, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 5, 3, 2013),
#  ('Human/Incendiary /Field Burning ', 'New Mexico', 5, 3, 2013),
#  ('Human/Incendiary /Other/ known ', 'New York', 6, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'California', 6, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'New Mexico', 6, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Oklahoma', 6, 3, 2013),
#  ('Human/Incendiary /Other/ known ', 'Oklahoma', 6, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 6, 3, 2013),
#  ('Human/Fire Use /Resource Mgmt ', 'Oklahoma', 6, 3, 2013),
#  ('Human/Incendiary /Other/ known ', 'Oklahoma', 6, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Wyoming', 6, 3, 2013),
#  ('Human/Equipment /Power Line ', 'South Dakota', 6, 3, 2013),
#  ('Human/Incendiary /Field Burning ', 'South Dakota', 6, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 6, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 6, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 6, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 7, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 7, 3, 2013),
#  ('Human/Accidental/Recreation', 'Arkansas', 7, 3, 2013),
#  ('Human/Fire Use /Resource Mgmt ', 'Oklahoma', 7, 3, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'Arizona', 7, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Tennessee', 7, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 7, 3, 2013),
#  ('Human/Incendiary /Field Burning ', 'New Mexico', 7, 3, 2013),
#  ('Human/Accidental/Agricultural', 'Georgia', 7, 3, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 7, 3, 2013),
#  ('Natural /Other/ known ', 'South Dakota', 7, 3, 2013),
#  ('Human/Equipment /Power Line ', 'New Mexico', 7, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 7, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 7, 3, 2013),
#  ('Human/Campfire /Other/ unknown ', 'Arizona', 7, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'New Mexico', 8, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 8, 3, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 8, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Arkansas', 8, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 8, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 8, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Idaho', 8, 3, 2013),
#  (None, 'Colorado', 19, 5, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Florida', 8, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 8, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 8, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 8, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 8, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 8, 3, 2013),
#  ('Human/Fire Use /Other/ known ', 'Oklahoma', 9, 3, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'New Mexico', 9, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 9, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 9, 3, 2013),
#  ('Human/Accidental/Agricultural', 'Georgia', 9, 3, 2013),
#  ('Human/Accidental/Agricultural', 'Georgia', 9, 3, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'South Dakota', 9, 3, 2013),
#  ('Human/Fire Use /Resource Mgmt ', 'Idaho', 9, 3, 2013),
#  ('Human/Fire Use /Other/ known ', 'Washington', 9, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Washington', 9, 3, 2013),
#  ('Human/Equipment /Other/ known ', 'Wyoming', 10, 3, 2013),
#  ('Human/Accidental/Agricultural', 'Oregon', 10, 3, 2013),
#  ('Natural /Other/ unknown ', 'Wyoming', 10, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 10, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Arizona', 11, 3, 2013),
#  ('Human', 'Oklahoma', 11, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Wyoming', 11, 3, 2013),
#  (None, 'Wyoming', 11, 3, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'New Mexico', 11, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Texas', 11, 3, 2013),
#  ('Human/Railroads /Other/ unknown ', 'Montana', 11, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arkansas', 12, 3, 2013),
#  ('Natural /Lightning ', 'Florida', 12, 3, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 12, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 12, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 12, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 12, 3, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'New Mexico', 12, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 12, 3, 2013),
#  ('Human/Railroads /Other/ unknown ', 'Montana', 12, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 12, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'California', 12, 3, 2013),
#  ('Natural /Lightning ', 'Mississippi', 12, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 12, 3, 2013),
#  ('Natural /Lightning ', 'New Mexico', 13, 3, 2013),
#  ('Human/Campfire /Other/ unknown ', 'California', 13, 3, 2013),
#  ('Natural /Other/ known ', 'Florida', 13, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'North Dakota', 13, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Tennessee', 13, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Idaho', 13, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 13, 3, 2013),
#  ('Human/Incendiary /Grudge Fire ', 'Missouri', 13, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 13, 3, 2013),
#  ('Human/Juveniles /Other/ known ', 'Arizona', 13, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 13, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oklahoma', 13, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 13, 3, 2013),
#  ('Human/Equipment /Other/ unknown ', 'Idaho', 13, 3, 2013),
#  ('Human/Fire Use /Other/ known ', 'Oklahoma', 13, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Texas', 13, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 13, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 13, 3, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'Nevada', 14, 3, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'Nevada', 14, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 14, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 14, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'Utah', 14, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Colorado', 14, 3, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 14, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 14, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 14, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'North Carolina', 14, 3, 2013),
#  ('Human/Arson/Adult', 'Texas', 15, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 15, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Mississippi', 15, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 15, 3, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'New Mexico', 15, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 15, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'California', 15, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'Wyoming', 15, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'North Carolina', 15, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'South Dakota', 15, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Oklahoma', 15, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 15, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 15, 3, 2013),
#  ('Human/Incendiary /Field Burning ', 'California', 15, 3, 2013),
#  ('Human/Equipment /Exhaust ', 'Arizona', 15, 3, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 15, 3, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'South Dakota', 15, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arizona', 15, 3, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 15, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'New Mexico', 15, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'South Dakota', 16, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Tennessee', 16, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Oklahoma', 16, 3, 2013),
#  ('Human/Juveniles /Recurrent ', 'South Dakota', 16, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oklahoma', 16, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'South Dakota', 16, 3, 2013),
#  ('Human', 'California', 16, 3, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'New Mexico', 16, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Arkansas', 16, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Arkansas', 16, 3, 2013),
#  ('Undetermined', 'New Mexico', 16, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 16, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 16, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'California', 16, 3, 2013),
#  ('Human/Fire Use /Slash Burning ', 'North Dakota', 16, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 16, 3, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 16, 3, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'South Dakota', 16, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oklahoma', 16, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oklahoma', 16, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Mississippi', 16, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Mississippi', 16, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 16, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'Utah', 16, 3, 2013),
#  ('Human/Other', 'New Mexico', 16, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'New Mexico', 16, 3, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'South Dakota', 17, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Tennessee', 17, 3, 2013),
#  ('Undetermined', 'Texas', 17, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Nevada', 17, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Tennessee', 17, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'Utah', 17, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'New Mexico', 17, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Washington', 17, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 17, 3, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 17, 3, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 18, 3, 2013),
#  ('Natural /Lightning ', 'Tennessee', 18, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'Mississippi', 18, 3, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 18, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'New Mexico', 18, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 18, 3, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 18, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Arizona', 18, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Arizona', 18, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 18, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 18, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'New Mexico', 18, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'New Mexico', 18, 3, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'South Dakota', 19, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'California', 19, 3, 2013),
#  ('Natural /Lightning ', 'North Carolina', 19, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 19, 3, 2013),
#  ('Human/Accidental/Recreation', 'Washington', 19, 3, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'North Dakota', 19, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'Oklahoma', 19, 3, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 19, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 19, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'South Dakota', 20, 3, 2013),
#  ('Undetermined', 'Oklahoma', 20, 3, 2013),
#  ('Human', 'Nevada', 20, 3, 2013),
#  ('Natural', 'Washington', 20, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arizona', 20, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 20, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'Mississippi', 20, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'South Dakota', 20, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'Oklahoma', 20, 3, 2013),
#  ('Natural /Lightning ', 'North Carolina', 20, 3, 2013),
#  (None, 'Colorado', 19, 5, 2013),
#  ('Human/Equipment /Vehicle ', 'New Mexico', 20, 3, 2013),
#  (None, 'Wyoming', 20, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oregon', 21, 3, 2013),
#  ('Human/Incendiary /Other/ known ', 'Arizona', 21, 3, 2013),
#  ('Human/Fire Use /Slash Burning ', 'New Mexico', 21, 3, 2013),
#  ('Human/Equipment /Exhaust ', 'New Mexico', 21, 3, 2013),
#  ('Human/Other', 'New Mexico', 21, 3, 2013),
#  ('Human/Other', 'New Mexico', 21, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 21, 3, 2013),
#  ('Human', 'North Dakota', 21, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'California', 21, 3, 2013),
#  ('Natural', 'Florida', 21, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 21, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 22, 3, 2013),
#  ('Natural /Other/ known ', 'North Dakota', 22, 3, 2013),
#  ('Human/Arson/Adult', 'Mississippi', 22, 3, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'New Mexico', 22, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 22, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'New Mexico', 22, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'New Mexico', 22, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Idaho', 22, 3, 2013),
#  ('Undetermined', 'Maryland', 22, 3, 2013),
#  ('Human/Incendiary /Field Burning ', 'New Mexico', 22, 3, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'New Mexico', 23, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'California', 23, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'New Mexico', 23, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 23, 3, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 23, 3, 2013),
#  ('Undetermined', 'Texas', 24, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'New Mexico', 24, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'Washington', 24, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Nevada', 24, 3, 2013),
#  ('Human/Incendiary /Field Burning ', 'Oklahoma', 24, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'New Mexico', 25, 3, 2013),
#  ('Human/Campfire /Other/ unknown ', 'New Mexico', 25, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 25, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'South Dakota', 25, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 25, 3, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 25, 3, 2013),
#  ('Human/Accidental/Recreation', 'Michigan', 25, 3, 2013),
#  ('Human/Accidental/Agricultural', 'Texas', 25, 3, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 25, 3, 2013),
#  ('Undetermined', 'California', 25, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 25, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Oklahoma', 25, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Montana', 25, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Montana', 25, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Oregon', 26, 3, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 26, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 26, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Utah', 26, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 26, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 26, 3, 2013),
#  ('Human/Accidental/Agricultural', 'Illinois', 26, 3, 2013),
#  ('Human/Equipment /Other/ known ', 'South Dakota', 26, 3, 2013),
#  ('Human/Fire Use /Slash Burning ', 'New Mexico', 26, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'California', 26, 3, 2013),
#  ('Human/Incendiary /Field Burning ', 'Utah', 26, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oregon', 26, 3, 2013),
#  ('Human/Smoking /Smoking ', 'California', 26, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Montana', 26, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 26, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 26, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 26, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Nevada', 26, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 26, 3, 2013),
#  ('Natural /Other/ known ', 'Arizona', 26, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'South Dakota', 27, 3, 2013),
#  ('Undetermined', 'Texas', 27, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Oklahoma', 27, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Oklahoma', 27, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'South Dakota', 27, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 27, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 27, 3, 2013),
#  ('Natural /Other/ unknown ', 'Wyoming', 27, 3, 2013),
#  ('Human/Incendiary /Other/ known ', 'Arizona', 27, 3, 2013),
#  ('Human/Fire Use /Other/ known ', 'Washington', 27, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'New Mexico', 27, 3, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Texas', 27, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 27, 3, 2013),
#  ('Human/Fire Use /Right-of-way ', 'Colorado', 27, 3, 2013),
#  ('Human/Incendiary /Other/ known ', 'Oklahoma', 27, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 27, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Indiana', 27, 3, 2013),
#  ('Human/Campfire /Other/ unknown ', 'Montana', 27, 3, 2013),
#  ('Human/Arson/Adult', 'Hawaii', 28, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 28, 3, 2013),
#  ('Natural', 'Washington', 28, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 28, 3, 2013),
#  ('Human/Equipment /Exhaust ', 'Missouri', 28, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 28, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'Mississippi', 28, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Tennessee', 28, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 28, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arkansas', 28, 3, 2013),
#  ('Human/Equipment /Power Line ', 'California', 28, 3, 2013),
#  ('Human/Accidental/Recreation', 'Oklahoma', 28, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 28, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 28, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'South Dakota', 28, 3, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'California', 28, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Missouri', 28, 3, 2013),
#  ('Human/Incendiary /Trash Burning ', 'South Dakota', 28, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 28, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 28, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'Oklahoma', 28, 3, 2013),
#  (None, 'Colorado', 19, 5, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 28, 3, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Mississippi', 28, 3, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'Oklahoma', 29, 3, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 29, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'South Dakota', 29, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 29, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Florida', 29, 3, 2013),
#  ('Human', 'Nevada', 29, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 29, 3, 2013),
#  ('Human/Accidental/Industrial', 'Louisiana', 29, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'New York', 29, 3, 2013),
#  (None, 'Utah', 29, 3, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 29, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'California', 29, 3, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'South Dakota', 29, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 29, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 29, 3, 2013),
#  ('Human/Fire Use /Land Clearing ', 'Wyoming', 29, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 29, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'South Dakota', 29, 3, 2013),
#  ('Human/Incendiary /Other/ known ', 'Florida', 30, 3, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 30, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'New Mexico', 30, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Utah', 30, 3, 2013),
#  ('Human/Other', 'California', 30, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'South Dakota', 30, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Montana', 30, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'North Carolina', 30, 3, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'North Carolina', 30, 3, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'South Dakota', 30, 3, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Idaho', 30, 3, 2013),
#  ('Human/Equipment /Vehicle ', 'Utah', 30, 3, 2013),
#  ('Human/Incendiary /Field Burning ', 'Utah', 30, 3, 2013),
#  ('Human/Fire Use /Slash Burning ', 'Arizona', 30, 3, 2013),
#  (None, 'Nevada', 31, 3, 2013),
#  ('Human/Fire Use /Field Burning ', 'Montana', 31, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 31, 3, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Wyoming', 31, 3, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Texas', 31, 3, 2013),
#  ('Human/Fire Use /Slash Burning ', 'Oklahoma', 31, 3, 2013),
#  (None, 'Arizona', 1, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Wyoming', 1, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 1, 4, 2013),
#  ('Human/Fire Use /Other/ known ', 'Washington', 1, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Washington', 1, 4, 2013),
#  ('Human/Equipment /Other/ unknown ', 'Wyoming', 1, 4, 2013),
#  ('Human/Equipment /Other/ unknown ', 'Wyoming', 1, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Montana', 1, 4, 2013),
#  ('Undetermined', 'Ohio', 1, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'Utah', 1, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Montana', 1, 4, 2013),
#  ('Natural', 'Florida', 1, 4, 2013),
#  ('Natural', 'Florida', 1, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 1, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 1, 4, 2013),
#  ('Natural /Other/ known ', 'North Dakota', 1, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 1, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arizona', 1, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 1, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'South Dakota', 1, 4, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Arizona', 1, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'South Dakota', 2, 4, 2013),
#  ('Natural /Other/ unknown ', 'New Mexico', 2, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 2, 4, 2013),
#  ('Natural /Lightning ', 'Texas', 2, 4, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 2, 4, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 2, 4, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 2, 4, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 2, 4, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 2, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 2, 4, 2013),
#  ('Human/Accidental/Recreation', 'Michigan', 2, 4, 2013),
#  ('Human/Railroads /Other/ unknown ', 'Indiana', 2, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'Montana', 2, 4, 2013),
#  ('Human/Arson/Adult', 'South Dakota', 2, 4, 2013),
#  ('Human/Fire Use /Land Clearing ', 'New Mexico', 2, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'Wyoming', 2, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 2, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'South Dakota', 2, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 2, 4, 2013),
#  ('Human', 'Oregon', 2, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Kansas', 2, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'South Dakota', 2, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 2, 4, 2013),
#  ('Human/Miscellaneous /Fireworks/ Adult ', 'Montana', 2, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'South Dakota', 2, 4, 2013),
#  ('Human/Campfire /Other/ unknown ', 'New Mexico', 2, 4, 2013),
#  ('Human', 'Indiana', 3, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 3, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 3, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 3, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Nevada', 3, 4, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Montana', 3, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 3, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 3, 4, 2013),
#  ('Human/Incendiary /Field Burning ', 'New York', 3, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'South Dakota', 3, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'South Dakota', 3, 4, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'New Mexico', 3, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'North Carolina', 3, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'North Carolina', 3, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 3, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 4, 4, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'Arizona', 4, 4, 2013),
#  ('Human/Accidental/Recreation', 'Florida', 4, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'New York', 4, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 4, 4, 2013),
#  (None, 'Colorado', 23, 5, 2013),
#  ('Human/Incendiary /Field Burning ', 'Montana', 4, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'New Mexico', 4, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'South Dakota', 4, 4, 2013),
#  ('Human/Fire Use /Land Clearing ', 'Wyoming', 4, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Wyoming', 4, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'South Dakota', 4, 4, 2013),
#  ('Human/Fire Use /Slash Burning ', 'Wyoming', 4, 4, 2013),
#  ('Natural', 'Florida', 5, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Wyoming', 5, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 5, 4, 2013),
#  ('Human/Miscellaneous /Fireworks/ Adult ', 'Arizona', 5, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 5, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 5, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'Wyoming', 5, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Utah', 5, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'New York', 5, 4, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 5, 4, 2013),
#  ('Human/Equipment /Other/ unknown ', 'Utah', 5, 4, 2013),
#  ('Human/Incendiary /Slash Burning ', 'South Dakota', 5, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'New York', 5, 4, 2013),
#  ('Human/Juveniles /Other/ known ', 'Montana', 5, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'South Dakota', 5, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Nebraska', 5, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Utah', 6, 4, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 6, 4, 2013),
#  ('Human/Fire Use /Land Clearing ', 'New Mexico', 6, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 6, 4, 2013),
#  ('Natural', 'Florida', 6, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'Utah', 6, 4, 2013),
#  ('Undetermined', 'Kansas', 6, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Utah', 6, 4, 2013),
#  ('Human/Juveniles /Other/ known ', 'Arizona', 6, 4, 2013),
#  ('Human/Fire Use /Resource Mgmt ', 'Oklahoma', 6, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'North Carolina', 6, 4, 2013),
#  ('Human/Incendiary /Other/ known ', 'North Carolina', 6, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'South Dakota', 6, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'New York', 7, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Maryland', 7, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 7, 4, 2013),
#  ('Human/Campfire /Other/ unknown ', 'New Mexico', 7, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arkansas', 7, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 7, 4, 2013),
#  ('Natural /Lightning ', 'New York', 7, 4, 2013),
#  ('Natural /Lightning ', 'New York', 7, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arizona', 7, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 7, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 7, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Arizona', 8, 4, 2013),
#  ('Human/Accidental/Recreation', 'Alabama', 8, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'New Mexico', 8, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 8, 4, 2013),
#  ('Human/Fire Use /Slash Burning ', 'New Mexico', 8, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 8, 4, 2013),
#  ('Human/Incendiary /Slash Burning ', 'New Mexico', 8, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'California', 9, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Maryland', 9, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Arizona', 9, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Pennsylvania', 9, 4, 2013),
#  ('Human/Accidental/Recreation', 'Florida', 9, 4, 2013),
#  ('Human/Fire Use /Slash Burning ', 'North Carolina', 9, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'New York', 10, 4, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 10, 4, 2013),
#  ('Human/Campfire /Other/ known ', 'Montana', 10, 4, 2013),
#  ('Human/Arson/Adult', 'Florida', 10, 4, 2013),
#  ('Human/Arson/Adult', 'Florida', 10, 4, 2013),
#  ('Undetermined', 'Arizona', 10, 4, 2013),
#  ('Natural /Lightning ', 'Utah', 10, 4, 2013),
#  ('Human/Accidental/Agricultural', 'Iowa', 10, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'New Mexico', 10, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'Nevada', 10, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 10, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'Montana', 11, 4, 2013),
#  ('Human/Campfire /Other/ unknown ', 'Utah', 11, 4, 2013),
#  ('Human/Equipment /Exhaust ', 'Utah', 11, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Maryland', 11, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 11, 4, 2013),
#  (None, 'Florida', 11, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 11, 4, 2013),
#  ('Human/Accidental/Agricultural', 'Texas', 12, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 12, 4, 2013),
#  ('Natural /Other/ unknown ', 'Oklahoma', 12, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'New Mexico', 12, 4, 2013),
#  ('Human/Accidental/Agricultural', 'Nevada', 12, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 12, 4, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'California', 13, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 13, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 13, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 13, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 13, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'New Mexico', 13, 4, 2013),
#  ('Human/Campfire /Other/ unknown ', 'Arizona', 14, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'New Mexico', 14, 4, 2013),
#  ('Natural /Lightning ', 'Florida', 14, 4, 2013),
#  ('Human/Campfire /Other/ unknown ', 'Washington', 14, 4, 2013),
#  ('Human', 'Arizona', 14, 4, 2013),
#  ('Human', 'Arizona', 14, 4, 2013),
#  ('Human', 'Arizona', 14, 4, 2013),
#  ('Human', 'Arizona', 14, 4, 2013),
#  ('Human', 'Arizona', 14, 4, 2013),
#  ('Human', 'Arizona', 14, 4, 2013),
#  ('Human', 'Arizona', 14, 4, 2013),
#  ('Human', 'Arizona', 14, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'North Carolina', 14, 4, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 14, 4, 2013),
#  ('Human/Fire Use /Slash Burning ', 'North Carolina', 14, 4, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Arizona', 14, 4, 2013),
#  ('Human/Incendiary /Field Burning ', 'New Mexico', 14, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'New Mexico', 15, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'New Mexico', 15, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'California', 15, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 15, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 15, 4, 2013),
#  ('Human/Fire Use /Slash Burning ', 'North Carolina', 15, 4, 2013),
#  ('Human/Equipment /Power Line ', 'Georgia', 16, 4, 2013),
#  ('Human/Accidental/Recreation', 'Minnesota', 16, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Washington', 16, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'Montana', 16, 4, 2013),
#  ('Undetermined', 'Arkansas', 16, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'New Mexico', 16, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'New Mexico', 16, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Mississippi', 16, 4, 2013),
#  ('Human/Campfire /Other/ unknown ', 'California', 16, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'Michigan', 16, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Oklahoma', 16, 4, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Washington', 17, 4, 2013),
#  ('Natural /Other/ known ', 'Idaho', 17, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'South Dakota', 17, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Oregon', 18, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Oregon', 18, 4, 2013),
#  ('Undetermined', 'Florida', 18, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Arizona', 18, 4, 2013),
#  ('Undetermined', 'Texas', 18, 4, 2013),
#  ('Human/Fire Use /Slash Burning ', 'Oregon', 18, 4, 2013),
#  ('Human/Equipment /Other/ unknown ', 'California', 18, 4, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'New Mexico', 19, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 19, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 19, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'New Mexico', 19, 4, 2013),
#  ('Natural', 'Oregon', 19, 4, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Nevada', 19, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 19, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'Arizona', 19, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'California', 19, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Massachusetts', 19, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Washington', 19, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 19, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Nevada', 19, 4, 2013),
#  ('Human/Equipment /Other/ unknown ', 'Arizona', 20, 4, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 20, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'Arizona', 20, 4, 2013),
#  ('Human/Fire Use /Burning Dump ', 'Arizona', 20, 4, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'Oregon', 20, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 20, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 20, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 20, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'North Dakota', 21, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 21, 4, 2013),
#  ('Human/Incendiary /Slash Burning ', 'Oregon', 21, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'South Dakota', 21, 4, 2013),
#  ('Human/Incendiary /Other/ known ', 'Arizona', 21, 4, 2013),
#  ('Natural /Other/ unknown ', 'California', 21, 4, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'North Dakota', 21, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'Utah', 21, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'California', 21, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 21, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'New Mexico', 21, 4, 2013),
#  ('Human/Miscellaneous /Burning Building ', 'North Dakota', 22, 4, 2013),
#  ('Human/Fire Use /Other/ known ', 'Washington', 22, 4, 2013),
#  ('Human/Incendiary /Slash Burning ', 'California', 22, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'Utah', 22, 4, 2013),
#  ('Human/Equipment /Other/ known ', 'New York', 22, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Massachusetts', 22, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'New Mexico', 22, 4, 2013),
#  ('Undetermined', 'Ohio', 22, 4, 2013),
#  ('Human/Fire Use /Land Clearing ', 'New York', 22, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'New Mexico', 22, 4, 2013),
#  ('Human/Miscellaneous /Fireworks/ Adult ', 'Utah', 22, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Massachusetts', 22, 4, 2013),
#  ('Human/Accidental/Agricultural', 'Wisconsin', 23, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'North Dakota', 23, 4, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 23, 4, 2013),
#  ('Human/Incendiary /Field Burning ', 'Wisconsin', 23, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Nevada', 23, 4, 2013),
#  ('Human/Incendiary /Field Burning ', 'Utah', 23, 4, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Arizona', 24, 4, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'South Dakota', 24, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'North Carolina', 24, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'Colorado', 24, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'Montana', 24, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'North Dakota', 24, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 24, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 24, 4, 2013),
#  ('Natural /Other/ unknown ', 'California', 24, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Arizona', 24, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 24, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Arizona', 24, 4, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 24, 4, 2013),
#  ('Natural /Other/ known ', 'New Mexico', 24, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'New Mexico', 24, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 24, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 25, 4, 2013),
#  ('Human/Fire Use /Slash Burning ', 'Washington', 25, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'Idaho', 25, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oregon', 25, 4, 2013),
#  ('Human/Equipment /Other/ known ', 'South Dakota', 25, 4, 2013),
#  ('Human/Equipment /Exhaust ', 'New Mexico', 25, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Oklahoma', 25, 4, 2013),
#  ('Human/Accidental/Agricultural', 'South Dakota', 25, 4, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 26, 4, 2013),
#  ('Natural /Other/ known ', 'South Dakota', 26, 4, 2013),
#  ('Human/Smoking /Smoking ', 'New Mexico', 26, 4, 2013),
#  ('Undetermined', 'North Carolina', 26, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'North Dakota', 26, 4, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'California', 26, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Iowa', 26, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'California', 26, 4, 2013),
#  ('Human/Accidental/Agricultural', 'California', 26, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Virginia', 26, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'Wyoming', 26, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Montana', 26, 4, 2013),
#  ('Human/Equipment /Other/ known ', 'Florida', 26, 4, 2013),
#  ('Human/Incendiary /Other/ known ', 'Montana', 26, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'South Dakota', 26, 4, 2013),
#  ('Human/Fire Use /Land Clearing ', 'Montana', 26, 4, 2013),
#  ('Natural /Other/ unknown ', 'California', 26, 4, 2013),
#  ('Human/Accidental/Recreation', 'Arizona', 26, 4, 2013),
#  ('Human/Campfire /Other/ unknown ', 'South Dakota', 26, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'South Dakota', 26, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Wyoming', 26, 4, 2013),
#  ('Natural /Other/ unknown ', 'South Dakota', 26, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'Montana', 26, 4, 2013),
#  ('Human/Equipment /Other/ unknown ', 'Montana', 27, 4, 2013),
#  ('Human/Fire Use /Slash Burning ', 'North Dakota', 27, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 27, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'New Mexico', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 27, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 27, 4, 2013),
#  ('Human/Incendiary /Other/ known ', 'California', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 27, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'North Dakota', 27, 4, 2013),
#  ('Natural /Other/ known ', 'North Dakota', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Washington', 27, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'New Mexico', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 27, 4, 2013),
#  ('Human/Campfire /Other/ unknown ', 'Virginia', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Arizona', 27, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 27, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 27, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Oregon', 27, 4, 2013),
#  ('Human/Fire Use /Trash Burning ', 'New Mexico', 27, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'North Dakota', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'New Mexico', 27, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 27, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 27, 4, 2013),
#  ('Human/Juveniles /Other/ unknown ', 'Minnesota', 27, 4, 2013),
#  ('Human/Fire Use /Other/ unknown ', 'South Dakota', 27, 4, 2013),
#  ('Human/Fire Use /Field Burning ', 'South Dakota', 27, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'New York', 27, 4, 2013),
#  ('Human/Incendiary /Field Burning ', 'South Dakota', 28, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 28, 4, 2013),
#  ('Natural /Other/ unknown ', 'North Dakota', 28, 4, 2013),
#  ('Human/Fire Use /Other/ known ', 'Arizona', 28, 4, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Arizona', 28, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'North Dakota', 28, 4, 2013),
#  ('Human/Campfire /Cooking/warming ', 'New Mexico', 28, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oregon', 28, 4, 2013),
#  ('Undetermined', 'Iowa', 28, 4, 2013),
#  ('Human/Arson/Adult', 'Puerto Rico', 28, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Oregon', 28, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 28, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 28, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 28, 4, 2013),
#  ('Human/Equipment /Vehicle ', 'Arizona', 28, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Minnesota', 28, 4, 2013),
#  ('Human/Equipment /Power Line ', 'Arizona', 28, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Oregon', 28, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 28, 4, 2013),
#  ('Human/Accidental/Agricultural', 'California', 28, 4, 2013),
#  ('Undetermined', 'Iowa', 28, 4, 2013),
#  ('Undetermined', 'Minnesota', 28, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 28, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Minnesota', 28, 4, 2013),
#  ('Human/Miscellaneous /Other/ known ', 'Texas', 28, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 28, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Minnesota', 28, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'New Mexico', 28, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'South Dakota', 28, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 28, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 28, 4, 2013),
#  ('Human/Incendiary /Other/ known ', 'North Dakota', 28, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Minnesota', 28, 4, 2013),
#  (None, 'Alaska', 28, 4, 2013),
#  ('Human/Incendiary /Recurrent ', 'California', 28, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'South Dakota', 28, 4, 2013),
#  ('Human/Juveniles /Ignition Devices ', 'Minnesota', 28, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 28, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Iowa', 28, 4, 2013),
#  ('Natural /Other/ unknown ', 'California', 29, 4, 2013),
#  ('Human/Accidental/Agricultural', 'California', 29, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'Minnesota', 29, 4, 2013),
#  ('Human/Miscellaneous /Other/ unknown ', 'North Dakota', 29, 4, 2013),
#  ('Human/Incendiary /Other/ unknown ', 'Minnesota', 29, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Oregon', 29, 4, 2013),
#  ('Human/Incendiary /Trash Burning ', 'Nebraska', 29, 4, 2013),
#  ...]

# %%
# flask setup
app = Flask(__name__)

# %%
#############################################
# /api/v1.0/interactive_pie
#############################################
def interactive_pie(fire_cause,st,year):
    session = Session(engine)
    
    date_tobs = session.query(func.min(measurement.tobs),func.avg(measurement.tobs),func.max(measurement.tobs)).filter(measurement.date >= start).filter(measurement.date <= end).all()  
           
@app.route("/")
def welcome():
    return("Available Routes:<br/> /api/v1.0/interactive_pie/<fire_cause>/<st>/<year>")

@app.route("/api/v1.0/interactive_pie")
def interactive_pie(fire_cause, st, year):
    session = Session(engine)    
    pie_results = session.query(fire_table.fire_cause, fire_table.st, fire_table.year)\
    .filter(fire_table.fire_cause == fire_cause)\
    .filter(fire_table.st == st)\
    .filter(fire_table.year == year).all()
    
    session.close()
    
    pie_string = []
    for fire_cause, st, year in pie_results:
        pie_data_dict = {}
        pie_data_dict["fire_cause"] = fire_cause
        pie_data_dict["st"] = st
        pie_data_dict["year"] = year
        all_dates_prcp.append(precip_data_dict)
    return jsonify(pie_string)

if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [31/Aug/2020 20:24:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Aug/2020 20:24:36] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [31/Aug/2020 20:26:29] "GET /Human/California/2014 HTTP/1.1" 404 -
# 127.0.0.1 - - [31/Aug/2020 20:26:34] "GET /Human/California/2014/ HTTP/1.1" 404 -
# 127.0.0.1 - - [31/Aug/2020 20:26:44] "GET / HTTP/1.1" 200 -

# %%
#############################################
# /api/v1.0/tobs
#############################################

# @app.route("/api/v1.0/tobs")
# def tobs():
#     session = Session(engine)
    
#     #Define One year ago
#     one_yr_ago = dt.date(2017,8,23) - dt.timedelta(days = 365)
    
#     #Define most active station
#     most_active_st = session.query(measurement.station, func.count(measurement.station)).group_by(measurement.station)\
#                                                     .order_by(func.count(measurement.station).desc()).limit(1).all()

#     #Generate results
#     tobs_results = session.query(measurement.date, measurement.tobs).filter(measurement.station == most_active_st[0][0]).filter(measurement.date >= one_yr_ago).all()
    
#     most_active_tobs_oneYear = []
#     for date, tobs in tobs_results:
#         tobs_data_dict = {}
#         tobs_data_dict["date"] = date
#         tobs_data_dict["tobs"] = tobs
#         most_active_tobs_oneYear.append(tobs_data_dict)
#     return jsonify(most_active_tobs_oneYear)

# %%
#############################################
# /api/v1.0/<start>/<end>
#############################################

# @app.route("/api/v1.0/<start>/<end>")
# def start_and_end(start,end):
#     session = Session(engine)
    
#     date_tobs = session.query(func.min(measurement.tobs),func.avg(measurement.tobs),func.max(measurement.tobs)).filter(measurement.date >= start).filter(measurement.date <= end).all()  
                                              
    
#     return jsonify(date_tobs)
# if __name__ == '__main__':
#     app.run(debug=False)
